# %% [markdown]
# # Python Fundamentals for Seismology — Notebook 1
# ## How Python Programs Run and How to Read Errors
#
# *Python Fundamentals for Seismology*
#
# Run each cell in order. Modify values and re-run.

# %% [markdown]
# ## Learning objectives
# - Understand how Python executes code top-to-bottom
# - Distinguish script vs notebook execution
# - Learn to read tracebacks correctly

# %%
print("Hello, Python is running top-to-bottom.")

# %% [markdown]
# ## Execution order
# Python executes code **in order**. Variables only exist after the line runs.

# %%
# Try running this cell before defining x below (you'll get an error)
# print(x)

x = 10
print("x is now defined:", x)

# %% [markdown]
# ## Reading tracebacks
# Always read from the **bottom** line upward to find the real cause.

# %%
# This will raise an error on purpose
def divide(a, b):
    return a / b

divide(10, 0)
