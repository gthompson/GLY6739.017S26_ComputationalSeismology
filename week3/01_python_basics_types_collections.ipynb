# %% [markdown]
# # Notebook 1 — Python basics: types and collections
# *A hands-on introduction with runnable examples and exercises.*
#
# Run each code cell. Edit values and re-run.

# %% [markdown]
# ## Variables and basic types

# %%
a = 12
b = 3.5
c = True
d = "hello"
e = None

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
print(e, type(e))

# %% [markdown]
# ## Strings

# %%
s = "  Volcano Seismology  "
print(s.strip())
print(s.upper())
print(s[0:4])

name = "Glenn"
n = 250_000
print(f"{name} has {n:,} events.")

# %% [markdown]
# ## Lists, tuples, dicts

# %%
stations = ["MBGH", "MBBY", "MBLG"]
stations.append("MBWH")
print(stations)

coords = (16.7, -62.2)
print(coords)

inventory = {"MBGH": 330, "MBBY": 250}
print(inventory["MBGH"])
