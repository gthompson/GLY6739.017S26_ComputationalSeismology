# %% [markdown]
# # Python Fundamentals for Seismology — Notebook 2
# ## Core Data Types and Containers
#
# *Python Fundamentals for Seismology*
#
# Run each cell in order. Modify values and re-run.

# %% [markdown]
# ## Numbers, booleans, and strings

# %%
a = 5
b = 2.0
c = True
d = "MBGH"
e = None

for v in [a, b, c, d, e]:
    print(v, type(v))

# %% [markdown]
# ## Lists, tuples, dicts

# %%
stations = ["MBGH", "MBBY", "MBLG"]
coords = (16.7, -62.2)
elev = {"MBGH": 330, "MBBY": 250}

print(stations)
print(coords)
print(elev["MBGH"])

# %% [markdown]
# ## Mutability matters

# %%
a = [1, 2, 3]
b = a
b.append(4)
print("a:", a)
print("b:", b)
